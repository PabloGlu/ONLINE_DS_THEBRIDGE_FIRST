# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![ejercicios.png](attachment:ejercicios.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: COLECCIONES Y FUNCIONES

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste varios ejercicios de programación libre a completar sobre Colecciones y Funciones. Descarga este notebook en tu ordenador y trabaja en local.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente y puedas participar en dicha sesión.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Contenidos

# %% [markdown]
# ## Ejercicio 1
# Eleva todos los elementos de la lista al cuadrado
# > ```ejer_2 = [1,2,3,4,5]```

# %%
ejer_2 = [1,2,3,4,5]

def square(args): # No conseguía que devolviese ejer_2 modificado
  for i in args:
    print(f"Antes {i}")
    i = i ** 2
    print(f"Despues {i}")


  return args

square(ejer_2)
# Out:
# Antes 1
# Despues 1
# Antes 2
# Despues 4
# Antes 3
# Despues 9
# Antes 4
# Despues 16
# Antes 5
# Despues 25
# [1, 2, 3, 4, 5]

# %%
ejer_2 = [1,2,3,4,5]

def square(args): # Así que he hecho otra versión que crea una nueva lista sin modificar ejer_2
  ejer_2_squared = []
  for i in args:
    print(f"Antes {i}")
    squared = i ** 2
    print(f"Despues {squared}")
    ejer_2_squared.append(squared)
  print(ejer_2_squared)
  return ejer_2_squared

square(ejer_2)
# Out:
# Antes 1
# Despues 1
# Antes 2
# Despues 4
# Antes 3
# Despues 9
# Antes 4
# Despues 16
# Antes 5
# Despues 25
# [1, 4, 9, 16, 25]
# [1, 4, 9, 16, 25]

# %%
num = [1, 2, 3, 4, 5]
square_num = [n ** 2 for n in num] # Bucle for dentro de una lista? Esto lo he visto curioseando en Youtube, y me ha parecido precioso.
print(square_num)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Ejercicio 2
# Haz un programa que detecte todos los duplicados de un elemento en una lista:
# * Utiliza una variable duplicado para asignarle el valor del elemento del que queremos encontrar todos sus duplicados.
# * El programa debe devolver todos los índices de los elementos duplicados.
# * Aplícalo para encontrar los duplicados de "un", "es" y "binario" de:
#
# >```ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]```

# %%
# ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]

# # duplicate_1 = ejer_3.copy()
# # print(duplicate_1)

# a = ejer_3.copy()
# print(a)


# duplicates = []
# for i, value in enumerate(a):
#   for j, value in enumerate(a):
#     if a[i] == a[j]:
#         duplicates.append(i)

# print(duplicates)

# print("-" * 100)

# duplicates = []
# for i, value in enumerate(a):
#   a1 = a.pop(i)
#   print(f"Prueba:{a1}")
#   for j, value in enumerate(a1):
#     if a[i] == a[j]:
#         duplicates.append(i)

# print(duplicates)

# print("-" * 100)

# eq = [index for index, (x, y) in enumerate(zip(a, a)) if x == y]
# print(eq)

# print("-" * 100)



# def detect_dupli(*args, **kwargs):
#   duplis = []
#   for i, value in enumerate(args):
#     if args[i] == kwargs[i]:
#       duplis.append(i)
#   print(duplis)

# detect_dupli(a, b)

# def detect_dupli(*args):
#   duplis = []
#   for i, value in range(len(args)):
#     for j in range(len(args)):
#       if args[i] == args[j]:
#         duplis.append([args[i], args[j]])
#   print(duplis)

# detect_dupli(duplicate_1)


# def detect_dupli(*args):
#   for i, word in enumerate(args):
#     print(f"I: {i}: {word}")
#   return args

# detect_dupli(duplicate_1)



# dupli_1 = set(duplicate_1)
# print(dupli_1)

# ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]

# a = ejer_3.copy()
# b = tuple(a)


# def find_duplicates(list):
#   index = []
#   for i, word in enumerate(list):
#     for j, word in enumerate(list):
#       if list[i] == list[j]:
#         index.append(i)

#   return index



# dupli_list = find_duplicates(a)
# print(dupli_list)

# print("-" * 100)

# ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]

# a = ejer_3.copy()
# b = set(a)
# print(len(a))
# print(len(b))
# print(f"set:{b}")

# def find_duplicates(list):
#   index = []
#   for i, word in enumerate(list):
#     for j, word in enumerate(list):
#       if list[i] == list[j]:
#         index.append(i)

#   return index



# dupli_list = find_duplicates(a)
# print(dupli_list)

# print("-" * 100)

# %%
ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]

a = ejer_3.copy()

seen = set()
dupes = set()

for x in a:
    if x in seen:
        dupes.add(x)
    else:
        seen.add(x)

print(f"Los elementos duplicados en la lista son {dupes}")
# Out:
# Los elementos duplicados en la lista son {'es', 'binario'}

# %%
ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]

a = ejer_3.copy()



def find_dupi(list):
  seen = set()
  dupes = set()
  for i in list:
    if i in seen:
      dupes.add(i)
    else:
      seen.add(i)

  return dupes

dupi_words = find_dupi(a)

print(f"Las palabras duplicadas son {dupi_words}")
# Out:
# Las palabras duplicadas son {'es', 'binario'}

# %%
ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]

a = ejer_3.copy()



def find_dupi(list):
  seen = set()
  dupes = set()
  for i, x in enumerate(list):
    if x in seen:
      dupes.add(i)
    else:
      seen.add(x)

  return dupes

duplicates_def = find_dupi(a)

print(f"Las posiciones de los elementos duplicados son: {duplicates_def}")
# Out:
# Las posiciones de los elementos duplicados son: {13, 15}

# %%
# Acabo de volver a leer el ejercicio con detenimiento. Hay que buscar los duplicados de 3 elementos concretos "un", "es" y "binario".
# Yo llevo un rato intentado crear una función que busques duplicados con los propios elementos dentro de la lista de strings.
# He entendido mi error, pero ha sido un viaje interesante.

# %%
ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]

a = ejer_3.copy()

def find_dupli_un(list):
  seen = set()
  dupes = set()
  for i, x in enumerate(list):
    if x == "un" or x == "es" or x == "binario":
      dupes.add(i)
    else:
      seen.add(x)
  return dupes

find_dupli_un(a)
# Out:
# {2, 3, 7, 13, 15}

# %% [markdown]
# ## Ejercicio 3
# 1. ¿Cuántas veces se repite el 3 en la siguiente tupla?
# 2. Crea una tupla nueva con los elementos desde la posicion 5 a la 10.
# 3. ¿Cuántos elementos tiene la tupla `ejer_3`?
# > ```ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)```

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)

lista_1 = list(ejer_9)

def count_dupli(list):
  dupli = 0
  for i, x in enumerate(list):
    if x == 3:
      print(f"Posición {i}, número {x}")
      dupli = dupli + 1

  print(f"Este número se repite {dupli} veces")


count_dupli(lista_1)

print("-" * 100)

lista_2 = lista_1[5:11]
tupla_2 = tuple(lista_2)
print(f"2. Crea una tupla nueva con los elementos desde la posicion 5 a la 10 \n{tupla_2}")

print("-" * 100)

# Como pone ejer_3 por si acaso te dejo hecho la longitud de ambos.

ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)

print(f"La longitud de la tupla inicial ejer_9 es de {len(ejer_9)} elementos")

print(f"La longitud de la lista ejer_3 del ejercicio anterior es de {len(ejer_3)} elementos")
# Out:
# Posición 0, número 3
# Posición 2, número 3
# Posición 5, número 3
# Posición 11, número 3
# Posición 12, número 3
# Posición 21, número 3
# Posición 22, número 3
# Este número se repite 7 veces
# ----------------------------------------------------------------------------------------------------
# 2. Crea una tupla nueva con los elementos desde la posicion 5 a la 10
# (3, 29, 45, 67, 78, 90)
# ----------------------------------------------------------------------------------------------------
# La longitud de la tupla inicial ejer_9 es de 26 elementos
# La longitud de la lista ejer_3 del ejercicio anterior es de 16 elementos

# %% [markdown]
# ## Ejercicio 4
# Comprueba si el numero 60 esta en la tupla del ejercicio 3

# %%
ejer_4 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
lista_4 = list(ejer_4)

def detect_number(list, num):
  for i, x in enumerate(list):
    if x == num:
      print(f"El número {x}, está en la posición {i}")
    else:
      print(f"No hemos encontrado el numero {num} en {x}")


  print(f"Final del programa")

detect_number(ejer_4, 60)
# Out:
# No hemos encontrado el numero 60 en 3
# No hemos encontrado el numero 60 en 20
# No hemos encontrado el numero 60 en 3
# No hemos encontrado el numero 60 en 47
# No hemos encontrado el numero 60 en 19
# No hemos encontrado el numero 60 en 3
# No hemos encontrado el numero 60 en 29
# No hemos encontrado el numero 60 en 45
# No hemos encontrado el numero 60 en 67
# No hemos encontrado el numero 60 en 78
# No hemos encontrado el numero 60 en 90
# No hemos encontrado el numero 60 en 3
# No hemos encontrado el numero 60 en 3
# No hemos encontrado el numero 60 en 5
# No hemos encontrado el numero 60 en 2
# No hemos encontrado el numero 60 en 4
# No hemos encontrado el numero 60 en 7
# No hemos encontrado el numero 60 en 9
# No hemos encontrado el numero 60 en 4
# No hemos encontrado el numero 60 en 2
# No hemos encontrado el numero 60 en 4
# No hemos encontrado el numero 60 en 3
# No hemos encontrado el numero 60 en 3
# No hemos encontrado el numero 60 en 4
# ...

# %% [markdown]
# ## Ejercicio 5
# 1. Convierte la tupla del ejercicio 3 en una lista
# 2. Convierte la tupla del ejercicio 3 en un set
# 3. Convierte la tupla del ejercicio 3 en un diccionario. Usa también los indices

# %%
ejer_5 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
lista_5 = list(ejer_4)
set_5 = set(ejer_5)
dicci_5 = dict(enumerate(ejer_5))

print(f"\
\n 1. Convierte la tupla del ejercicio 3 en una lista \n {lista_5} {type(lista_5)}\
\n 2. Convierte la tupla del ejercicio 3 en un set \n {set_5} {type(set_5)}\
\n 3. Convierte la tupla del ejercicio 3 en un diccionario. Usa también los indices \n {dicci_5} {type(dicci_5)}")
# Out:
#  1. Convierte la tupla del ejercicio 3 en una lista
#  [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7] <class 'list'>
#  2. Convierte la tupla del ejercicio 3 en un set
#  {2, 3, 67, 5, 4, 7, 6, 9, 45, 78, 47, 19, 20, 90, 29} <class 'set'>
#  3. Convierte la tupla del ejercicio 3 en un diccionario. Usa también los indices
#  {0: 3, 1: 20, 2: 3, 3: 47, 4: 19, 5: 3, 6: 29, 7: 45, 8: 67, 9: 78, 10: 90, 11: 3, 12: 3, 13: 5, 14: 2, 15: 4, 16: 7, 17: 9, 18: 4, 19: 2, 20: 4, 21: 3, 22: 3, 23: 4, 24: 6, 25: 7} <class 'dict'>

# %% [markdown]
# ## Ejercicio 6
# Multiplica todos los valores del diccionario
# > ```ejer_6 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_6 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

dicci_6 = {}

for i, x in ejer_6.items():
  dicci_6 = i * x
  print(f"Multiplica todos los valores del diccionario{dicci_6}") # ¿Entiendo que la idea es multiplicar los valores por sus claves?
# Out:
# 11
# 44
# 99
# 176
# 275

# %% [markdown]
# ## Ejercicio 7
#
# 1. Crea un diccionario que describa un libro, con los siguientes campos o claves: "titulo","autor","idioma original","año de publicación".
# 2. Crea un a lista, llamada librería.
# 3. Añade cuatro libros a tu elección a la librería.

# %%
from pprint import pprint

dicci_7 = {"titulo": "","autor": "","idioma original": "","año de publicación": 0}
print(f"Crea un diccionario que describa un libro, con los siguientes campos o claves: \n{dicci_7}")

libreria = []

libro_1 = {
    "titulo": "Piel de Cordero",
    "autor": "Ledicia Costas",
    "idioma original":"castellano",
    "año de publicación":2024
    }

libro_2 = {
    "titulo": "Como ser mujer",
    "autor": "Caitlin Moran",
    "idioma original":"inglés",
    "año de publicación":2011
    }
libro_3 = {
    "titulo": "La invitada",
    "autor": "Simone de Beauvoir",
    "idioma original":"frances",
    "año de publicación":1943
    }
libro_4 = {
    "titulo": "Café de Artistas",
    "autor": "Camilo José Cela",
    "idioma original":"castellano",
    "año de publicación":1953
    }

libreria.append(libro_1)
libreria.append(libro_2)
libreria.append(libro_3)
libreria.append(libro_4)

pprint(libreria)
# Out:
# Crea un diccionario que describa un libro, con los siguientes campos o claves:
# {'titulo': '', 'autor': '', 'idioma original': '', 'año de publicación': 0}
# [{'autor': 'Ledicia Costas',
#   'año de publicación': 2024,
#   'idioma original': 'castellano',
#   'titulo': 'Piel de Cordero'},
#  {'autor': 'Caitlin Moran',
#   'año de publicación': 2011,
#   'idioma original': 'inglés',
#   'titulo': 'Como ser mujer'},
#  {'autor': 'Simone de Beauvoir',
#   'año de publicación': 1943,
#   'idioma original': 'frances',
#   'titulo': 'La invitada'},
#  {'autor': 'Camilo José Cela',
#   'año de publicación': 1953,
#   'idioma original': 'castellano',
#   'titulo': 'Café de Artistas'}]

# %% [markdown]
# ## Ejercicio 8
# Modifica los valores del idioma de todos los libros del ejercicio anterior para que sea "esperanto"

# %%
for libro in libreria:
  libro['idioma original'] = "esperanto"

pprint(libreria)
# Out:
# [{'autor': 'Ledicia Costas',
#   'año de publicación': 2024,
#   'idioma original': 'esperanto',
#   'titulo': 'Piel de Cordero'},
#  {'autor': 'Caitlin Moran',
#   'año de publicación': 2011,
#   'idioma original': 'esperanto',
#   'titulo': 'Como ser mujer'},
#  {'autor': 'Simone de Beauvoir',
#   'año de publicación': 1943,
#   'idioma original': 'esperanto',
#   'titulo': 'La invitada'},
#  {'autor': 'Camilo José Cela',
#   'año de publicación': 1953,
#   'idioma original': 'esperanto',
#   'titulo': 'Café de Artistas'}]
# [{'autor': 'Ledicia Costas',
#   'año de publicación': 2024,
#   'idioma original': 'esperanto',
#   'titulo': 'Piel de Cordero'},
#  {'autor': 'Caitlin Moran',
#   'año de publicación': 2011,
#   'idioma original': 'esperanto',
#   'titulo': 'Como ser mujer'},
#  {'autor': 'Simone de Beauvoir',
#   'año de publicación': 1943,
#   'idioma original': 'esperanto',
#   'titulo': 'La invitada'},
#  {'autor': 'Camilo José Cela',
#   'año de publicación': 1953,
# ...

# %% [markdown]
# ## Ejercicio 9
# 1. Escribe un programa que dada una variable titulo busque los libros que hay en la librería con ese título. Si no se encuentra debe devolver el mensaje `Ese no lo tengo, ¿mola?`
# 2. Pruena que el programa con uno de tus libros y con otro que no contenga tu librería.

# %%
print("-" * 100)

def find_book(libreria, titulo):
  for libro in libreria:
    if libro["titulo"] == titulo:
      print(f"¿{titulo}? Lo tengo!")
      pprint(libro)
      return(libro)
  print(f"¿{titulo}? Ese no lo tengo, ¿mola?")
  return None

find_book(libreria, "La invitada")

find_book(libreria, "Libro X")
# Out:
# ----------------------------------------------------------------------------------------------------
# ¿La invitada? Lo tengo!
# {'autor': 'Simone de Beauvoir',
#  'año de publicación': 1943,
#  'idioma original': 'esperanto',
#  'titulo': 'La invitada'}
# ¿Libro X? Ese no lo tengo, ¿mola?

# %% [markdown]
# ## Ejercicio 10
# Convierte el programa del ejercicio 2 en una función al que se le pase el valor a buscar como un argumento posicional

# %%
print("-" * 100)

def find_book(libreria, key, value):
  for libro in libreria:
    if libro[key] == value:
      print(f"¿{key}: {value}? Lo tengo!")
      pprint(libro)
      return(libro)
  print(f"¿{key}: {value}? Ese no lo tengo, ¿me sugieres alguno?")
  return None

find_book(libreria, "año de publicación", 2024)

find_book(libreria, "año de publicación", 2030)
# Out:
# ----------------------------------------------------------------------------------------------------
# ¿año de publicación: 2024? Lo tengo!
# {'autor': 'Ledicia Costas',
#  'año de publicación': 2024,
#  'idioma original': 'esperanto',
#  'titulo': 'Piel de Cordero'}
# ¿año de publicación: 2030? Ese no lo tengo, ¿me sugieres alguno?

# %% [markdown]
# ## Ejercicio 11
# Convierte el programa del ejercicio 9 en una función al que se le pasen como argumentos la librería, posicional, y el título, argumento keyword con valor "ninguno", por defecto.

# %%
def find_book(libreria, titulo=None):
  for libro in libreria:
    if libro["titulo"] == titulo:
      print(f"¿{titulo}? Lo tengo!")
      pprint(libro)
      return(libro)
  print(f"¿{titulo}? Ese no lo tengo, ¿me sugieres alguno?")
  return None

find_book(libreria, "Como ser mujer")

find_book(libreria, "2030")
# Out:
# ¿Como ser mujer? Lo tengo!
# {'autor': 'Caitlin Moran',
#  'año de publicación': 2011,
#  'idioma original': 'esperanto',
#  'titulo': 'Como ser mujer'}
# ¿2030? Ese no lo tengo, ¿me sugieres alguno?

# %% [markdown]
# ## Ejercicio 12
# Solicitar al usuario que ingrese su dirección email. Imprimir un mensaje indicando si la dirección es válida o no, valiéndose de una función para decidirlo. Una dirección se considerará válida si contiene el símbolo "@".

# %%
def verify_email(): # Este ha sido divertido
  email = input('Escribe tu email: ')
  verified = email.find("@")
  if verified >= 0:
    print("Congratulations, your email is verified!")
  else:
    print("Error! Please, correct your email")
  return verified

verify_email()
# Out:
# Escribe tu email: @@
# Congratulations, your email is verified!
# 0

# %% [markdown]
# ## Ejercicio 13
# Escribe una función que compruebe si un DNI es válido, devolviendo `True` en caso afirmativo.
# En primer lugar, el DNI debe tener entre 7 y 8 dígitos numéricos.
# Para saber si la letra del DNI es correcta puedes utilizar el siguiente fragmento de código:
# >```Python
# >DNI= 55555555
# >palabra='TRWAGMYFPDXBNJZSQVHLCKE'
# >print('La letra del DNI es: ', palabra[DNI%23])
# >````

# %%
# Lo he hecho de 3 maneras diferentes. Esta es simple pero sólo comprueba longitud realmente

dni= 55555555
palabra='TRWAGMYFPDXBNJZSQVHLCKE'
print('La letra del DNI es: ', palabra[DNI%23])

def verify_id(id):
  letra = palabra[DNI%23]
  if len(str(id)) == 7 or len(str(id)) == 8:
    print("Longitud DNI ok")
    if letra == palabra[DNI%23]:
      print("All", True)
  else:
    print("Verifique ID introducido")

verify_id(dni)
# Out:
# La letra del DNI es:  K
# Longitud DNI ok
# All True

# %%
# Esta siento que es más completa, la idea era que pudiese evaluar un DNI completo. Sé que hago un proceso "un poco" reiterativo.

dni= 55555555
palabra='TRWAGMYFPDXBNJZSQVHLCKE'
print('La letra del DNI es: ', palabra[DNI%23])

id_completo = str(dni) + palabra[DNI%23]
print(id_completo)


def verify_id(id):
  nums = id[:-1]
  letra = id[-1]
  print(nums, letra)
  if len(nums) == 7 or len(nums) == 8:
    print("Longitud DNI ok")
    if letra == palabra[DNI%23]:
      print("All", True)
  else:
    print("Verifique ID introducido")

verify_id(id_completo)
# Out:
# La letra del DNI es:  K
# 55555555K
# 55555555 K
# Longitud DNI ok
# All True

# %%
# Y este es el que más me gusta aunque me gustaría cambiar el modo de determinar si la letra es correcta.
# He cambiado la función para que haga el calculo de la letra con cada DNI introducido. Estoy contento!.
# Te dejo justo debajo un sencillo programa para sacar la letra correcta de cada combinación de números que quieras para tu DNI.

id_completo=input("Escriba su DNI con letra todo seguido") # Tienes que poner como letra "K".

def verify_id(id):
  nums = id[:-1]
  letra = id[-1]
  print(nums, letra)
  if len(nums) == 7 or len(nums) == 8:
    print("Longitud DNI ok")
    if letra == palabra[int(nums)%23]:
      print("All", True)
  else:
    print("Verifique ID introducido")

verify_id(id_completo)
# Out:
# Escriba su DNI con letra todo seguido55555555K
# 55555555 K
# Longitud DNI ok
# All True

# %%
# Sencillo programa para sacar la letra correcta de cada combinación de números que quieras para tu DNI.

numero_dni = input("Numero de DNI que quieras una letra para el ejercicio de arriba: ")

def dame_una_letra_para_mi_DNI(numero_dni):
  letra = palabra[int(numero_dni)%23]
  if len(numero_dni) != 7 and len(numero_dni) != 8:
    print("Te doy la letra pero el DNI está mal")
  return letra

dame_una_letra_para_mi_DNI(numero_dni)
# Out:
# Numero de DNI que quieras una letra para el ejercicio de arriba: 2222222
# 'P'
